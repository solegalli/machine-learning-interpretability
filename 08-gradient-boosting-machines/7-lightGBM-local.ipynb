# %% [markdown]
# # LightGBMs
#
# - [Online Course](https://www.trainindata.com/p/machine-learning-interpretability)
#
# Here I show a model for regression, but it's the same code, apart from the model, if you want to do classification.
#
# In case you have problems importing lightGBMs check out [this solution](https://stackoverflow.com/questions/76610527/cannot-import-lightgbm-error-with-pandas).

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

from lightgbm import LGBMRegressor

# %% [markdown]
# ### Load data

# %%
# load the California House price data from Scikit-learn
X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X = X.drop(columns=["Latitude", "Longitude"])

# display top 5 rows
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467

# %% [markdown]
# ### Split data

# %%
# let's separate into training and testing set

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

X_train.shape, X_test.shape
# Out:
# ((14448, 6), (6192, 6))

# %% [markdown]
# ## LightGBM

# %%
# fit model

gbm = LGBMRegressor(
    importance_type="gain",
    n_estimators=5,
    max_depth=3,
    random_state=3,
)

gbm.fit(X_train, y_train)
# Out:
# LGBMRegressor(importance_type='gain', max_depth=3, n_estimators=5,
#               random_state=3)

# %% [markdown]
# ## Eli5
#
# If you have problems to import eli5 with the latest version of sklearn, you need to go to the eli5 files that are stored in your local computer, and change a few lines of code as shown in [this PR](https://github.com/eli5-org/eli5/commit/840695d869e47b8e6cc05baca428d24881113fb6)
#
# More details also available [here](https://github.com/eli5-org/eli5/issues/39).

# %%
import eli5

# %% [markdown]
# ## Global explanations

# %%
# Feature importance (global)

eli5.show_weights(gbm, feature_names=X_train.columns.to_list())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.8378
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MedInc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1308
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AveOccup
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AveRooms
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0088
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HouseAge
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Population
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AveBedrms
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# the importance from light GBM 
# is not normalized

pd.Series(gbm.feature_importances_,
          index=X_train.columns.to_list()).sort_values(ascending=False)
# Out:
# MedInc        31005.383511
# AveOccup       4839.465012
# AveRooms        837.246979
# HouseAge        326.010893
# AveBedrms         0.000000
# Population        0.000000
# dtype: float64

# %%
# sum of all importances

total = pd.Series(gbm.feature_importances_).sum()
total
# Out:
# 37008.10639381409

# %%
# now the results match

pd.Series(gbm.feature_importances_ / total,
          index=X_train.columns.to_list()).sort_values(ascending=False)
# Out:
# MedInc        0.837800
# AveOccup      0.130768
# AveRooms      0.022623
# HouseAge      0.008809
# AveBedrms     0.000000
# Population    0.000000
# dtype: float64

# %% [markdown]
# ## Local explanations

# %%
# Display a few observations from test set

X_test.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 14740  4.1518      22.0  5.663073   1.075472      1551.0  4.180593
# 10101  5.7796      32.0  6.107226   0.927739      1296.0  3.020979
# 20566  4.3487      29.0  5.930712   1.026217      1554.0  2.910112
# 2670   2.4511      37.0  4.992958   1.316901       390.0  2.746479
# 15709  5.0049      25.0  4.319261   1.039578       649.0  1.712401

# %%
sample_id = 14740

# %%
eli5.show_prediction(
    gbm,
    X_test.loc[sample_id],
    feature_names=X_train.columns.to_list()
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y
#
# </b>
#
#
#     (score <b>1.983</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.068
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.003
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         MedInc
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.082
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         AveOccup
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %%
gbm.predict(X_test.loc[sample_id].to_frame().T)
# Out:
# array([1.98264895])

# %%
# manual calculation

# Bias + MedInc + AveOccup

2.068 - 0.003 - 0.082
# Out:
# 1.9829999999999999

# %% [markdown]
# In case you want to do the exercise manually, you can obtain the values for each tree, node and leaf like this:

# %%
booster = gbm.booster_

# %%
# print structure of tree

model = booster.dump_model()
model['tree_info']
# Out:
# [{'tree_index': 0,
#   'num_leaves': 8,
#   'num_cat': 0,
#   'shrinkage': 1,
#   'tree_structure': {'split_index': 0,
#    'split_feature': 0,
#    'split_gain': 6048.080078125,
#    'threshold': 5.012150000000001,
#    'decision_type': '<=',
#    'default_left': True,
#    'missing_type': 'None',
#    'internal_value': 2.06825,
#    'internal_weight': 0,
#    'internal_count': 14448,
#    'left_child': {'split_index': 1,
#     'split_feature': 0,
#     'split_gain': 1521.56005859375,
#     'threshold': 3.0686000000000004,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 2.03443,
#     'internal_weight': 11348,
#     'internal_count': 11348,
#     'left_child': {'split_index': 5,
#      'split_feature': 2,
#      'split_gain': 280.5539855957031,
#      'threshold': 4.205543464345156,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 1.99651,
#      'internal_weight': 5476,
#      'internal_count': 5476,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': 2.025979553893073,
#       'leaf_weight': 2032,
#       'leaf_count': 2032},
#      'right_child': {'leaf_index': 6,
#       'leaf_value': 1.9791256015413838,
#       'leaf_weight': 3444,
#       'leaf_count': 3444}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 862.2860107421875,
#      'threshold': 2.3470994314885725,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 2.06979,
#      'internal_weight': 5872,
#      'internal_count': 5872,
#      'left_child': {'leaf_index': 2,
#       'leaf_value': 2.1417976238447736,
#       'leaf_weight': 1296,
#       'leaf_count': 1296},
#      'right_child': {'leaf_index': 4,
#       'leaf_value': 2.04939734620722,
#       'leaf_weight': 4576,
#       'leaf_count': 4576}}},
#    'right_child': {'split_index': 2,
#     'split_feature': 0,
#     'split_gain': 1119.06005859375,
#     'threshold': 7.815150000000001,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 2.19204,
#     'internal_weight': 3100,
#     'internal_count': 3100,
#     'left_child': {'split_index': 4,
#      'split_feature': 5,
#      'split_gain': 394.3529968261719,
#      'threshold': 2.5911067193675894,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 2.1646,
#      'internal_weight': 2565,
#      'internal_count': 2565,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 2.225765594334285,
#       'leaf_weight': 747,
#       'leaf_count': 747},
#      'right_child': {'leaf_index': 5,
#       'leaf_value': 2.139462021706623,
#       'leaf_weight': 1818,
#       'leaf_count': 1818}},
#     'right_child': {'split_index': 6,
#      'split_feature': 0,
#      'split_gain': 35.80070114135742,
#      'threshold': 9.151950000000001,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 2.32359,
#      'internal_weight': 535,
#      'internal_count': 535,
#      'left_child': {'leaf_index': 3,
#       'leaf_value': 2.2979646516350107,
#       'leaf_weight': 270,
#       'leaf_count': 270},
#      'right_child': {'leaf_index': 7,
#       'leaf_value': 2.3497036184558855,
#       'leaf_weight': 265,
#       'leaf_count': 265}}}}},
#  {'tree_index': 1,
#   'num_leaves': 8,
#   'num_cat': 0,
#   'shrinkage': 0.1,
#   'tree_structure': {'split_index': 0,
#    'split_feature': 0,
#    'split_gain': 4933.02978515625,
#    'threshold': 5.13675,
#    'decision_type': '<=',
#    'default_left': True,
#    'missing_type': 'None',
#    'internal_value': 0,
#    'internal_weight': 0,
#    'internal_count': 14448,
#    'left_child': {'split_index': 1,
#     'split_feature': 0,
#     'split_gain': 1341.0799560546875,
#     'threshold': 2.8343000000000003,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': -0.028801,
#     'internal_weight': 11624,
#     'internal_count': 11624,
#     'left_child': {'split_index': 5,
#      'split_feature': 2,
#      'split_gain': 226.90699768066406,
#      'threshold': 3.9802386117136663,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0704953,
#      'internal_weight': 4637,
#      'internal_count': 4637,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': -0.037617461006140995,
#       'leaf_weight': 1445,
#       'leaf_count': 1445},
#      'right_child': {'leaf_index': 6,
#       'leaf_value': -0.0853788602457135,
#       'leaf_weight': 3192,
#       'leaf_count': 3192}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 796.5960083007812,
#      'threshold': 2.213969065179937,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.00113016,
#      'internal_weight': 6987,
#      'internal_count': 6987,
#      'left_child': {'leaf_index': 2,
#       'leaf_value': 0.07740716487019743,
#       'leaf_weight': 1090,
#       'leaf_count': 1090},
#      'right_child': {'leaf_index': 4,
#       'leaf_value': -0.015646975980965382,
#       'leaf_weight': 5897,
#       'leaf_count': 5897}}},
#    'right_child': {'split_index': 2,
#     'split_feature': 0,
#     'split_gain': 833.8410034179688,
#     'threshold': 6.825050000000001,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0.118549,
#     'internal_weight': 2824,
#     'internal_count': 2824,
#     'left_child': {'split_index': 4,
#      'split_feature': 5,
#      'split_gain': 281.8810119628906,
#      'threshold': 2.7432767466685033,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.0809598,
#      'internal_weight': 1910,
#      'internal_count': 1910,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.12660282841898887,
#       'leaf_weight': 792,
#       'leaf_count': 792},
#      'right_child': {'leaf_index': 5,
#       'leaf_value': 0.0486259056718748,
#       'leaf_weight': 1118,
#       'leaf_count': 1118}},
#     'right_child': {'split_index': 6,
#      'split_feature': 0,
#      'split_gain': 138.05499267578125,
#      'threshold': 7.815150000000001,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.1971,
#      'internal_weight': 914,
#      'internal_count': 914,
#      'left_child': {'leaf_index': 3,
#       'leaf_value': 0.15092508300087148,
#       'leaf_weight': 379,
#       'leaf_count': 379},
#      'right_child': {'leaf_index': 7,
#       'leaf_value': 0.22981150222219804,
#       'leaf_weight': 535,
#       'leaf_count': 535}}}}},
#  {'tree_index': 2,
#   'num_leaves': 8,
#   'num_cat': 0,
#   'shrinkage': 0.1,
#   'tree_structure': {'split_index': 0,
#    'split_feature': 0,
#    'split_gain': 4079.25,
#    'threshold': 4.626350000000001,
#    'decision_type': '<=',
#    'default_left': True,
#    'missing_type': 'None',
#    'internal_value': 0,
#    'internal_weight': 0,
#    'internal_count': 14448,
#    'left_child': {'split_index': 2,
#     'split_feature': 0,
#     'split_gain': 819.4080200195312,
#     'threshold': 2.6618500000000007,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': -0.0321793,
#     'internal_weight': 10571,
#     'internal_count': 10571,
#     'left_child': {'split_index': 6,
#      'split_feature': 2,
#      'split_gain': 180.73399353027344,
#      'threshold': 3.8174193761487856,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0678421,
#      'internal_weight': 4003,
#      'internal_count': 4003,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': -0.03236845972323958,
#       'leaf_weight': 1057,
#       'leaf_count': 1057},
#      'right_child': {'leaf_index': 7,
#       'leaf_value': -0.08056972406701662,
#       'leaf_weight': 2946,
#       'leaf_count': 2946}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 638.6439819335938,
#      'threshold': 2.4177921789514065,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0104438,
#      'internal_weight': 6568,
#      'internal_count': 6568,
#      'left_child': {'leaf_index': 3,
#       'leaf_value': 0.03976890924894246,
#       'leaf_weight': 1828,
#       'leaf_count': 1828},
#      'right_child': {'leaf_index': 4,
#       'leaf_value': -0.029808571487914465,
#       'leaf_weight': 4740,
#       'leaf_count': 4740}}},
#    'right_child': {'split_index': 1,
#     'split_feature': 0,
#     'split_gain': 1025.3599853515625,
#     'threshold': 6.370400000000001,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0.0877397,
#     'internal_weight': 3877,
#     'internal_count': 3877,
#     'left_child': {'split_index': 4,
#      'split_feature': 5,
#      'split_gain': 319.9840087890625,
#      'threshold': 2.686358805146184,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.0525163,
#      'internal_weight': 2639,
#      'internal_count': 2639,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.09778544685559369,
#       'leaf_weight': 981,
#       'leaf_count': 981},
#      'right_child': {'leaf_index': 5,
#       'leaf_value': 0.025731613741261775,
#       'leaf_weight': 1658,
#       'leaf_count': 1658}},
#     'right_child': {'split_index': 5,
#      'split_feature': 0,
#      'split_gain': 182.4510040283203,
#      'threshold': 7.815150000000001,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.162824,
#      'internal_weight': 1238,
#      'internal_count': 1238,
#      'left_child': {'leaf_index': 2,
#       'leaf_value': 0.12933449338959957,
#       'leaf_weight': 703,
#       'leaf_count': 703},
#      'right_child': {'leaf_index': 6,
#       'leaf_value': 0.20683034117011545,
#       'leaf_weight': 535,
#       'leaf_count': 535}}}}},
#  {'tree_index': 3,
#   'num_leaves': 8,
#   'num_cat': 0,
#   'shrinkage': 0.1,
#   'tree_structure': {'split_index': 0,
#    'split_feature': 0,
#    'split_gain': 3348.639892578125,
#    'threshold': 5.6077,
#    'decision_type': '<=',
#    'default_left': True,
#    'missing_type': 'None',
#    'internal_value': 0,
#    'internal_weight': 0,
#    'internal_count': 14448,
#    'left_child': {'split_index': 1,
#     'split_feature': 0,
#     'split_gain': 1212.1300048828125,
#     'threshold': 3.5631000000000004,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': -0.0195875,
#     'internal_weight': 12396,
#     'internal_count': 12396,
#     'left_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 340.44000244140625,
#      'threshold': 2.147103840818865,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0456317,
#      'internal_weight': 7319,
#      'internal_count': 7319,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': 0.006660544367677128,
#       'leaf_weight': 1064,
#       'leaf_count': 1064},
#      'right_child': {'leaf_index': 4,
#       'leaf_value': -0.054526850590188296,
#       'leaf_weight': 6255,
#       'leaf_count': 6255}},
#     'right_child': {'split_index': 2,
#      'split_feature': 5,
#      'split_gain': 501.6449890136719,
#      'threshold': 2.3696956593849223,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.0179579,
#      'internal_weight': 5077,
#      'internal_count': 5077,
#      'left_child': {'leaf_index': 2,
#       'leaf_value': 0.07857188788198496,
#       'leaf_weight': 1076,
#       'leaf_count': 1076},
#      'right_child': {'leaf_index': 3,
#       'leaf_value': 0.0016568259019774758,
#       'leaf_weight': 4001,
#       'leaf_count': 4001}}},
#    'right_child': {'split_index': 4,
#     'split_feature': 0,
#     'split_gain': 332.8659973144531,
#     'threshold': 7.815150000000001,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0.118327,
#     'internal_weight': 2052,
#     'internal_count': 2052,
#     'left_child': {'split_index': 5,
#      'split_feature': 1,
#      'split_gain': 165.13999938964844,
#      'threshold': 27.500000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.0944084,
#      'internal_weight': 1517,
#      'internal_count': 1517,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.07009044105710158,
#       'leaf_weight': 983,
#       'leaf_count': 983},
#      'right_child': {'leaf_index': 6,
#       'leaf_value': 0.13917342659804538,
#       'leaf_weight': 534,
#       'leaf_count': 534}},
#     'right_child': {'split_index': 6,
#      'split_feature': 1,
#      'split_gain': 31.873899459838867,
#      'threshold': 29.500000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.186147,
#      'internal_weight': 535,
#      'internal_count': 535,
#      'left_child': {'leaf_index': 5,
#       'leaf_value': 0.16404814985168936,
#       'leaf_weight': 294,
#       'leaf_count': 294},
#      'right_child': {'leaf_index': 7,
#       'leaf_value': 0.2131064554498651,
#       'leaf_weight': 241,
#       'leaf_count': 241}}}}},
#  {'tree_index': 4,
#   'num_leaves': 8,
#   'num_cat': 0,
#   'shrinkage': 0.1,
#   'tree_structure': {'split_index': 0,
#    'split_feature': 0,
#    'split_gain': 2761.469970703125,
#    'threshold': 4.533250000000001,
#    'decision_type': '<=',
#    'default_left': True,
#    'missing_type': 'None',
#    'internal_value': 0,
#    'internal_weight': 0,
#    'internal_count': 14448,
#    'left_child': {'split_index': 2,
#     'split_feature': 0,
#     'split_gain': 551.2109985351562,
#     'threshold': 2.5209500000000005,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': -0.027561,
#     'internal_weight': 10339,
#     'internal_count': 10339,
#     'left_child': {'split_index': 5,
#      'split_feature': 2,
#      'split_gain': 149.052001953125,
#      'threshold': 3.255343011240486,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0603599,
#      'internal_weight': 3426,
#      'internal_count': 3426,
#      'left_child': {'leaf_index': 0,
#       'leaf_value': -0.0028275576437678395,
#       'leaf_weight': 398,
#       'leaf_count': 398},
#      'right_child': {'leaf_index': 6,
#       'leaf_value': -0.06792193008737378,
#       'leaf_weight': 3028,
#       'leaf_count': 3028}},
#     'right_child': {'split_index': 3,
#      'split_feature': 5,
#      'split_gain': 458.6080017089844,
#      'threshold': 2.224385934672068,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': -0.0113063,
#      'internal_weight': 6913,
#      'internal_count': 6913,
#      'left_child': {'leaf_index': 3,
#       'leaf_value': 0.04567006823007047,
#       'leaf_weight': 1173,
#       'leaf_count': 1173},
#      'right_child': {'leaf_index': 4,
#       'leaf_value': -0.022949676541440017,
#       'leaf_weight': 5740,
#       'leaf_count': 5740}}},
#    'right_child': {'split_index': 1,
#     'split_feature': 0,
#     'split_gain': 722.0910034179688,
#     'threshold': 6.3058000000000005,
#     'decision_type': '<=',
#     'default_left': True,
#     'missing_type': 'None',
#     'internal_value': 0.0693485,
#     'internal_weight': 4109,
#     'internal_count': 4109,
#     'left_child': {'split_index': 4,
#      'split_feature': 5,
#      'split_gain': 245.0279998779297,
#      'threshold': 2.773738839776576,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.0409585,
#      'internal_weight': 2817,
#      'internal_count': 2817,
#      'left_child': {'leaf_index': 1,
#       'leaf_value': 0.07376695667380838,
#       'leaf_weight': 1259,
#       'leaf_count': 1259},
#      'right_child': {'leaf_index': 5,
#       'leaf_value': 0.014446412395615374,
#       'leaf_weight': 1558,
#       'leaf_count': 1558}},
#     'right_child': {'split_index': 6,
#      'split_feature': 1,
#      'split_gain': 128.9969940185547,
#      'threshold': 27.500000000000004,
#      'decision_type': '<=',
#      'default_left': True,
#      'missing_type': 'None',
#      'internal_value': 0.131248,
#      'internal_weight': 1292,
#      'internal_count': 1292,
#      'left_child': {'leaf_index': 2,
#       'leaf_value': 0.10514832502243128,
#       'leaf_weight': 768,
#       'leaf_count': 768},
#      'right_child': {'leaf_index': 7,
#       'leaf_value': 0.16950209546591766,
#       'leaf_weight': 524,
#       'leaf_count': 524}}}}}]

# %% [markdown]
# But the calculation is similar to what we saw for sklearn, so we won't do it manually here.
#
# LightGBM adds the contribution of each tree to get th final outcome.
#
# It is simpler than sklearn in that it does not multiply the contribution by the learning rate.
